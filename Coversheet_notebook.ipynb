# %% [markdown]
# <div style="background-color: #FFFFE0; padding: 20px; border-radius: 5px; border: 2px solid black; position: relative;">
#     <div style="position: absolute; top: 15px; left: 20px;">
#         <img src="./EDSA_logo_small_form.png" alt="EDSA Logo" style="height: 60px; width: auto;">
#     </div>
#         <div style="position: absolute; top: 15px; right: 20px;">
#         <img src="https://minerva.leeds.ac.uk/bbcswebdav/xid-57322668_2" alt="University of Leeds" style="height: 60px; width: auto;">
#     </div>
#     <h3 style="margin: 0; padding: 0; margin-top: 70px;">School of Geography</h3>
#     </br>
#     <hr>
#     <h2>COURSEWORK COVERSHEET</h2>
#     <h2>Late submissions and Extensions</h2>
#     <p style="margin: 0; padding: 0;"><strong>Module code:</strong> GEOG5305M</p>
#     <p style="margin: 0; padding: 0;"><strong>Module:</strong> EDSA Data Science Project</p>
#     <p style="margin: 0; padding: 0;"><strong>Component:</strong> Programmatic Analysis</p>
#     <p style="color: black;"><strong>Assessment weighting: </strong><a>50%</a></p>
#     <p style="color: black;"><strong>Due date: </strong><a> Thursday 4 September 2025 at 2pm (UK time)</a></p>
#     <p style="color: black;"><strong>Instructions:</strong> Please refer to the assessment brief and guidance on Minerva. Instructions for generating the requirements.json are at the bottom of this notebook. If you need to submit later, e.g. due to an extension, please get in touch with the module teaching team.
#     <h3>Academic Integrity declaration</h3>
#     <p>By submitting the work in this folder you confirm your compliance with the University’s definition of Academic Integrity as: “a commitment to good study practices and shared values which ensures that my work is a true expression of my own understanding and ideas, giving credit to others where their work contributes to mine”. Double-check that your referencing and use of quotations is consistent with this commitment.</p>
#     <p>You also confirm that your declared word count accurately reflects the number of words in your submission, excluding the overall title, Gen AI use acknowledgement, bibliography/reference list, text/numbers in tables and figures (although table and figure captions are included in the word count).</p>
# </div>

# %% [markdown]
# <div style="background-color: #eeeeee; padding: 15px; border-radius: 5px; border: 2px solid black; position: relative;">
#     <h3>Student ID number</h3>
#     <p>Type your student ID number below.</p>
# </div>

# %% [markdown]
# 201905652

# %% [markdown]
# <div style="background-color: #eeeeee; padding: 15px; border-radius: 5px; border: 2px solid black; position: relative;">
#     <h3>EDSA Data Science Project Title</h3>
#     <p>Type the name of your project below.</a>
# </div>

# %% [markdown]
# Sand Mobility Analysis, Gran Canaria

# %% [markdown]
# <div style="background-color: #eeeeee; padding: 15px; border-radius: 5px; border: 2px solid black; position: relative;">
#     <h3>Supervisor</h3>
#     <p>Type the name of your project supervisor below.</a>
# </div>

# %% [markdown]
# Dr. Na Yan

# %% [markdown]
# <div style="background-color: #eeeeee; padding: 15px; border-radius: 5px; border: 2px solid black; position: relative;">
#     <h3>Gen AI usage declaration</h3>
#         <p><strong>Type one of these AI usage statements into the cell below:<strong></p>
#         <p>I have made no use of Gen AI</p>
#         <p>I have used Gen AI only for the specific purposes outlined in my acknowledgements</p>
# </div>

# %% [markdown]
# X

# %% [markdown]
# <div style="background-color: #eeeeee; padding: 15px; border-radius: 5px; border: 2px solid black; position: relative;">
#     <h3>Gen AI acknowledgements</h3>
#     <p>If you have used Gen AI, use the below box for your acknowledgements. Please refer to the University's webpage on <a href="https://generative-ai.leeds.ac.uk/ai-and-assessments/acknowledging-use-of-ai/">Acknowledging use of Generative AI.</a>
# </div>

# %% [markdown]
# I have used Grammerly to aid in my punctuation and grammar.

# %% [markdown]
# ### **Creating your `requirements.json` file**
#
# An important part of your submission is the requirement to generate a `requirements.json` file. The purpose of this file is to create a precise record of your working environment. Specifically, the version of Python and every package you have used. This guarantees that the markers can replicate your setup exactly, which is fundamental to a fair and accurate assessment of your work.
#
# It is vital that this file is generated from within your main `Code_Notebook.ipynb` itself, as this is the environment we need to analyse. You can do this in three steps:
#
# **1. Position the code**
#
# First, copy the entire code block provided below. Then, paste it into a brand new cell at the very end of your analysis notebook (`Code_Notebook.ipynb`), not this current Coversheet_Notebook! It must be the absolute final cell.
#
# **2. Perform a clean run**
#
# Before creating the file, you need to verify that your notebook executes perfectly from a fresh start.
#
# *   From the toolbar, select `Kernel > Restart & Run All Cells`.
# *   Allow the notebook to complete its run from the first cell to the last.
# *   Carefully scroll through the entire notebook to check for any errors. If you find any, you must fix them and repeat this "Restart & Run All" step until it completes without issue.
#
# **3. Generate the `requirements.json` File**
#
# Once you have a clean, error-free run, you can proceed to the final cell that contains the generator code. Execute this cell on its own. It will produce the `requirements.json` file in your project folder.
#
# ***Note: If an entire run of the notebook is not possible, run the cells that import your packages, as this is what is captured in the requirements file. In the case of errors you cannot resolve, or if running the Notebook is not feasible in terms of time you have available due to long run times, it is still important to generate a `requirements.json` file - you can do this by manually executing every code cell near the top of your notebook that contains an import statement (e.g., import pandas, import numpy, etc.) and then running the code below.***

# %%
# ===================================================================================
# GENERATE REQUIREMENTS FILE
#
# Before you submit, you must run this code in a final cell in your Code_Notebook,
# NOT INSIDE THIS COVERSHEET_NOTEBOOK. This will create the requirements.json
# file which is required for marking.
#
# Make sure you have followed the instructions above to run your
# entire Code_Notebook from top to bottom BEFORE running this code.
# ===================================================================================

import json
from importlib import metadata
import sys
import datetime

print("Generating requirements.json file...")

try:
    # Get all installed packages and their version numbers
    installed_packages = {dist.metadata['Name']: dist.metadata['Version']
                          for dist in metadata.distributions()}
    
    # Sort the package list alphabetically
    sorted_packages = dict(sorted(installed_packages.items()))

    # Get the Python version
    python_version = f"{sys.version_info.major}.{sys.version_info.minor}.{sys.version_info.micro}"

    # Get the current timestamp in UTC
    generation_timestamp_utc = datetime.datetime.now(datetime.timezone.utc).isoformat() # <--- ADDED

    # Combine all data into a single dictionary
    environment_data = {
        "generation_timestamp_utc": generation_timestamp_utc, # <--- ADDED
        "python_version": python_version,
        "packages": sorted_packages
    }

    # Define the output file name
    file_name = "requirements.json"

    # Write the data to the requirements.json file in the current directory
    with open(file_name, 'w') as f:
        json.dump(environment_data, f, indent=4)

    print("-" * 50)
    print(f"SUCCESS: The '{file_name}' file has been created successfully.")
    print("Please check the file is present and as expected before you submit.")
    print("-" * 50)

except Exception as e:
    print("-" * 50)
    print(f"ERROR: An error occurred while generating the file.")
    print("Please contact a member of the teaching team for help, including any errors or warnings.")
    print(f"Error details: {e}")
    print("-" * 50)

# %% [markdown]
# <div style="background-color: #FFFFE0; padding: 10px; border-radius: 5px; border: 1px solid gray; position: relative;">
#     <h2>END OF NOTEBOOK</h2>
